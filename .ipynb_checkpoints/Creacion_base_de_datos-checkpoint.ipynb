# %%
pip install astroquery
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lightkurve
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.8/265.8 kB 3.4 MB/s eta 0:00:003.9 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 5.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 11.2 MB/s eta 0:00:00
# ...
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11373 sha256=82db9975730d6627222f086985db796f9aa2704387c1f89850811cf8836baf17
#   Stored in directory: /home/pater/.cache/pip/wheels/f5/60/60/28df6c25f4d22b73d1a2b1c7e4842a5e2178e35e47b62e8e9a
# ...
#   Created wheel for memoization: filename=memoization-0.4.0-py3-none-any.whl size=50450 sha256=6beddd5aff498e5f5dba37858a8e5a4b54616cf37a7f205f03edfae27087a7ca
# ...

# %%
pip install --upgrade numpy scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from astroquery.mast import Observations
import lightkurve as lk
import os

# %%
#Url Pater
url = "/home/pater/Desktop/CosasPater/UNAL/2023-02NovenoSemestre/IA/DataProyect/"

# %%
#Url Ari
url = "C:/Users/ASUS/OneDrive/Documentos/2023-2/Inteligencia/Proyecto/Curvas_de_luz/"

# %%
def descargar_curvas_de_luz(kepler_id,url):
    # Buscar las curvas de luz de un objetivo específico
    obs = lk.search_lightcurve(kepler_id, author='Kepler')
    lc = obs[-1].download()
    df = pd.DataFrame({'time': lc.time.value,  # Tiempo
                       'flux': lc.flux,  # Flujo
                       'flux_err': lc.flux_err  # Error en el flujo
                      })
    df.to_csv(f'{url}LC_{kepler_id}.csv', index=False)

# %%
Star_info = pd.read_csv('cumulative.csv')
Star_info
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# ...

# %%
Star_info[2234:]
# Out:
#       rowid     kepid kepoi_name    kepler_name koi_disposition  \
# 2234   2235   8081905  K02619.01  Kepler-1292 b       CONFIRMED
# 2235   2236  11465950  K02620.01            NaN       CANDIDATE
# 2236   2237   9996632  K02621.01            NaN  FALSE POSITIVE
# 2237   2238   4665571  K02393.01            NaN       CANDIDATE
# 2238   2239   4829935  K02395.01            NaN  FALSE POSITIVE
# ...     ...       ...        ...            ...             ...
# 9559   9560  10031643  K07984.01            NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01            NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01            NaN       CANDIDATE
# 9562   9563  10147276  K07987.01            NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01            NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 2234        CANDIDATE      1.000              0              0              0
# ...

# %%
contenido = os.listdir(url)
L_Str = []
for Str in contenido:
    Str = int(Str[3:-4])
    L_Str.append(Str)

# %%
KEPID = Star_info[2234:]['kepid']
i = 0
for name in KEPID:
    if name in L_Str:
        i += 1
        continue
    else:
        Id = str(name)
        descargar_curvas_de_luz(Id,url)
        continue

# %%
i
# Out:
# 7330
